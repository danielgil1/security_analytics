# %%
import sys
sys.path.append("../src")
import preprocessing
import cconfig
import clustering

# Plotting defaults
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# # Load data and preprocess

# %%
# load original data in dataframes, sample, select some features and scale
df,df_Normal,df_Attack=preprocessing.data_load(0.1,None ,False)
X=preprocessing.data_scale(df[cconfig.SELECTED_FEATURES_FLOW])
X_Normal=preprocessing.data_scale(df_Normal[cconfig.SELECTED_FEATURES_FLOW])
X_Attack=preprocessing.data_scale(df_Attack[cconfig.SELECTED_FEATURES_FLOW])

# %% [markdown]
# # KMEANS

# %%
# fit kmeans model with normal day data
kmeans=clustering.kmeans_train(X_Normal,2)

# predictions with attack dataset
labels=clustering.kmeans_predict(X_Attack,kmeans)

# dimensionality reduction
XR=preprocessing.get_pc(X_Attack,2)

# print results
clustering.clustering_print_results(df_Attack,labels,cconfig.SELECTED_FEATURES_FLOW,XR,True,True)
# Out:
# Variability explained by the PC: 0.5578401635092627
#
# Cluster 0: 9534 data points
#                   src            dst                    start  \
# 166400   192.168.10.5  62.161.94.230  2017-07-07 17:54:41.921
# 159968  192.168.10.25   192.168.10.3  2017-07-07 18:43:55.363
# 145112  192.168.10.16  192.168.10.50  2017-07-07 18:07:51.905
#
#                          finish  total_duration protocol  total_bytes  \
# 166400  2017-07-07 17:54:42.413        0.492037  TLSv1.2         1212
# 159968  2017-07-07 18:43:55.419        0.056708     LDAP         7448
# 145112  2017-07-07 18:07:52.045        0.139813      FTP          288
#
#         total_packets  src_ports  dst_ports       pps        bps         bpp  \
# 166400             14      54108        443   28.4531    2463.23   86.571429
# 159968             30      53572        389  529.0300  131339.00  248.266667
# 145112             49      45916         21  350.4680    2059.89    5.877551
#
#         attack  cluster         x         y
# 166400       1        0 -2.392300 -0.860651
# 159968       1        0 -2.131452  0.010727
# 145112       1        0 -2.383911 -0.946695
#
# Cluster 1: 8260 data points
#                    src             dst                    start  \
# 101540  162.242.240.67   192.168.10.50  2017-07-07 19:02:59.381
# 114314  172.217.12.174    192.168.10.5  2017-07-07 18:45:34.958
# 158580   192.168.10.19  54.248.121.156  2017-07-07 17:14:44.461
#
#                          finish  total_duration protocol  total_bytes  \
# 101540  2017-07-07 19:03:02.614        3.233773      TCP        46460
# 114314  2017-07-07 18:45:35.387        0.428944     OCSP         1179
# 158580  2017-07-07 17:14:45.077        0.615882      TCP         2172
#
#         total_packets  src_ports  dst_ports       pps       bps         bpp  \
# 101540             48         80      62173  14.84334  14367.12  967.916667
# 114314             10         80      55993  23.31310   2748.61  117.900000
# 158580             12        443      38576  19.48430   3526.65  181.000000
#
#         attack  cluster         x         y
# 101540       1        1  2.827754 -0.067680
# 114314       1        1 -0.295462  0.451528
# 158580       1        1 -0.535610  0.295911
# done.

# %% [markdown]
# # DBSCAN

# %%
# fit and predict
dblabels=clustering.dbscan_fit_predict(0.5,100,X)

# do dimensionality reduction to plot
XR=preprocessing.get_pc(X,2)

# print and plot
clustering.clustering_print_results(df,dblabels,cconfig.SELECTED_FEATURES_FLOW,XR,True,True)
# Out:
# Estimated number of clusters: 4
# Estimated number of noise points: 3107
# Total points: 32490
# Variability explained by the PC: 0.5650638197536567
#
# Cluster -1: 3107 data points
#                  src            dst                    start  \
# 39567  172.217.10.78  192.168.10.12  2017-07-03 13:28:07.231
# 46907  172.217.6.206  192.168.10.51  2017-07-03 14:25:32.696
# 47868    172.217.7.1  192.168.10.25  2017-07-03 14:47:10.307
#
#                         finish  total_duration protocol  total_bytes  \
# 39567  2017-07-03 13:28:07.578        0.347580  TLSv1.2         9465
# 46907  2017-07-03 14:25:33.003        0.307022  TLSv1.2        10335
# 47868  2017-07-03 14:47:10.556        0.248064    TLSv1         7461
#
#        total_packets  src_ports  dst_ports      pps      bps         bpp  \
# 39567            297        443      34908  854.480  27231.0   31.868687
# 46907             71        443      33371  231.254  33662.1  145.563380
# 47868            109      63552        443  439.403  30076.9   68.449541
#
#        attack  cluster         x         y
# 39567       0       -1  0.662771 -0.025556
# 46907       0       -1  0.245475  0.278983
# 47868       0       -1 -1.515581 -0.400251
#
# Cluster 0: 13726 data points
#                    src            dst                    start  \
# 21782   151.101.44.134  192.168.10.25  2017-07-03 14:04:43.842
# 73891    192.168.10.14   68.67.180.45  2017-07-03 12:06:54.828
# 10870  125.209.226.232  192.168.10.12  2017-07-03 13:40:14.619
#
#                         finish  total_duration protocol  total_bytes  \
# 21782  2017-07-03 14:04:44.487        0.644382    TLSv1         1535
# 73891  2017-07-03 12:06:55.006        0.177956  TLSv1.2          709
# 10870  2017-07-03 13:40:16.036        1.417120      TCP         4681
#
#        total_packets  src_ports  dst_ports      pps      bps         bpp  \
# 21782             18      56475        443  27.9337  2382.13   85.277778
# 73891              8      49829        443  44.9549  3984.13   88.625000
# 10870             20      50692        443  14.1131  3303.18  234.050000
#
#        attack  cluster         x         y
# 21782       0        0 -1.744748 -0.461800
# 73891       0        0 -1.793946 -0.329406
# 10870       0        0 -1.174727 -0.493031
#
# Cluster 1: 12977 data points
#                     src            dst                    start  \
# 20401   151.101.208.166  192.168.10.12  2017-07-03 13:22:23.874
# 22475      151.101.46.2  192.168.10.25  2017-07-03 14:44:07.419
# 142692     192.168.10.9    52.40.24.51  2017-07-03 12:07:44.622
#
#                          finish  total_duration protocol  total_bytes  \
# 20401   2017-07-03 13:22:24.178        0.303722    TLSv1         3006
# 22475   2017-07-03 14:44:07.541        0.122477      TCP          524
# 142692  2017-07-03 12:07:45.183        0.560419  TLSv1.2         3397
#
#         total_packets  src_ports  dst_ports      pps      bps         bpp  \
# 20401              15        443      39622  49.3873  9897.21  200.400000
# 22475               9         80      63041  73.4832  4278.35   58.222222
# 142692             13        443       1194  23.1969  6061.54  261.307692
#
#         attack  cluster         x         y
# 20401        0        1  0.022245  0.297412
# 22475        0        1  0.159200  0.469741
# 142692       0        1 -0.594627 -0.009038
#
# Cluster 2: 146 data points
#                  src            dst                    start  \
# 65371  192.168.10.12   54.192.37.61  2017-07-03 12:07:07.765
# 86551  192.168.10.16  93.184.216.16  2017-07-03 12:24:39.036
# 48796    172.217.7.6  192.168.10.51  2017-07-03 14:34:35.466
#
#                         finish  total_duration protocol  total_bytes  \
# 65371  2017-07-03 12:07:07.960        0.195127    TLSv1         8326
# 86551  2017-07-03 12:24:39.328        0.291823  TLSv1.2        14515
# 48796  2017-07-03 14:34:35.987        0.521178  TLSv1.2         8090
#
#        total_packets  src_ports  dst_ports      pps      bps         bpp  \
# 65371             73        443      40134  374.115  42669.6  114.054795
# 86551            104        443      36718  356.380  49739.1  139.567308
# 48796             83        443      44015  159.255  15522.5   97.469880
#
#        attack  cluster         x         y
# 65371       0        2  0.237559  0.459609
# 86551       0        2  0.540225  0.341430
# 48796       0        2  0.387917  0.177217
#
# Cluster 3: 2534 data points
#                    src            dst                    start  \
# 142333    192.168.10.9    52.2.96.185  2017-07-03 12:47:09.406
# 101540  162.242.240.67  192.168.10.50  2017-07-07 19:02:59.381
# 100893  162.242.240.67  192.168.10.50  2017-07-07 19:02:35.397
#
#                          finish  total_duration protocol  total_bytes  \
# 142333  2017-07-03 12:47:11.926        2.520079     HTTP        37271
# 101540  2017-07-07 19:03:02.614        3.233773      TCP        46460
# 100893  2017-07-07 19:02:41.293        5.896240      TCP        41995
#
#         total_packets  src_ports  dst_ports       pps        bps         bpp  \
# 142333             57         80      63239  22.61834  14789.620  653.877193
# 101540             48         80      62173  14.84334  14367.120  967.916667
# 100893             52         80      61526   8.81918   7122.336  807.596154
#
#         attack  cluster         x         y
# 142333       0        3  2.967399 -0.005786
# 101540       1        3  3.829810 -0.086911
# 100893       1        3  4.012688 -0.333597
# done.
