# %%
import sys
sys.path.append("../src")
import preprocessing
import cconfig
import clustering

# Plotting defaults
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# # Load data and preprocess

# %%
# select type of features and default values
selected_features=cconfig.SELECTED_FEATURES_PACKET
dataset_type=cconfig.DATASET_TYPE_PACKET
max_num_clusters=cconfig.DEFAULT_NUM_CLUSTERS

# %%
# load original data in dataframes, sample, select some features and scale
df,df_Normal,df_Attack=preprocessing.data_load(0.01,None,False,dataset_type)
print(df.columns)
X=preprocessing.data_scale(df[selected_features])
X_Normal=preprocessing.data_scale(df_Normal[selected_features])
X_Attack=preprocessing.data_scale(df_Attack[selected_features])
# Out:
# Index(['start_time', 'finish_time', 'src_ip', 'dst_ip', 'total_bytes',
#        'total_common_protocols', 'total_src_ports', 'total_dst_ports',
#        'total_http_errors', 'total_failures', 'duration'],
#       dtype='object')

# %% [markdown]
# # KMEANS

# %%
# find the best number of clusters
df_silhouette = clustering.kmeans_get_number_clusters(X_Normal)

# select best number of clusters for kmeans
max_num_clusters=df_silhouette.iloc[df_silhouette.score.idxmax() ]['Num Clusters']

# plot the result for reference
df_silhouette.plot(x='Num Clusters', y='score')

# %%
# fit kmeans model with normal day data
kmeans=clustering.kmeans_train(X_Normal,int(max_num_clusters))

# predictions with attack dataset
labels=clustering.kmeans_predict(X_Attack,kmeans)

# dimensionality reduction
XR=preprocessing.get_pc(X_Attack,2)

# print results
clustering.clustering_print_results(df_Attack,labels,cconfig.SELECTED_FEATURES_FLOW,XR,True,True,dataset_type+'_kmeans')
# Out:
# Variability explained by the PC: 0.5702768981455615
#
# Exporting PACKET_KMEANS...
# Number of clusters: 5
#
# Cluster 0: 140 data points
#
# Cluster 1: 5 data points
#
# Cluster 2: 14 data points
#
# Cluster 3: 3 data points
#
# Cluster 4: 3 data points
#
# DONE.
# -------------------------------------------------------

# %%
# print anomalies
index_anomalies=clustering.kmeans_anomalies(X_Attack,kmeans)
df_anomalies=df_Attack.iloc[index_anomalies,:]
df_anomalies
# Out:
#                     start_time              finish_time         src_ip  \
# 11547  2017-07-07 19:29:35.779  2017-07-07 19:31:19.315  195.209.111.7
# 1557   2017-07-07 18:10:03.396  2017-07-07 18:13:04.267  162.213.63.56
# 9921   2017-07-07 17:25:40.963  2017-07-07 19:35:32.428   192.168.10.8
# 10846  2017-07-07 17:01:08.162  2017-07-07 20:01:21.990   192.168.10.9
# 9272   2017-07-07 17:54:10.718  2017-07-07 19:00:56.391   192.168.10.5
#
#                 dst_ip  total_bytes  total_common_protocols  total_src_ports  \
# 11547    192.168.10.15        16100                       0                2
# 1557     192.168.10.15      1650274                       0                2
# 9921   173.241.242.143        45124                       0               36
# 10846     192.168.10.3       199716                       0               42
# 9272     50.63.243.230         9400                       0               29
#
#        total_dst_ports  total_http_errors  total_failures      duration  \
# 11547               14                  0               1    103.536021
# 1557                 7                  0               0    180.870983
# 9921                 2                  0               0   7791.465066
# 10846                6                  0               0  10813.828580
# 9272                 1                  0               0   4005.673018
#
#        cluster         x         y
# 11547        1  3.911713  9.003181
# 1557         3  2.646103  3.786083
# 9921         4  4.913165 -4.544815
# 10846        4  7.171571 -4.697673
# 9272         4  2.988578 -3.538847

# %% [markdown]
# # DBSCAN

# %%
# define hyper parameters for dbscan
eps=0.5
min_samples=26

# fit and predict
dblabels=clustering.dbscan_fit_predict(eps,min_samples,X)

# do dimensionality reduction to plot
XR=preprocessing.get_pc(X,2)

# print and plot
clustering.clustering_print_results(df,dblabels,cconfig.SELECTED_FEATURES_FLOW,XR,True,True,dataset_type+'_dbscan')
# Out:
# Estimated number of clusters: 1
# Estimated number of noise points: 89
# Total points: 398
# Variability explained by the PC: 0.5277529024658413
#
# Exporting PACKET_DBSCAN...
# Number of clusters: 2
#
# Cluster -1: 89 data points
#
# Cluster 0: 309 data points
#
# DONE.
# -------------------------------------------------------

# %% [markdown]
# # OPTIC

# %%
# define hyper params for optics
eps=1.5
min_samples=20

# predict using optics
labels=clustering.optics_fit_predict(X,min_samples,'dbscan', eps)

# do dimensionality reduction to plot
XR=preprocessing.get_pc(X,2)

# print and plot
clustering.clustering_print_results(df,labels,cconfig.SELECTED_FEATURES_FLOW,XR,True,True,dataset_type+'_optic')
# Out:
# Variability explained by the PC: 0.5277529024658413
#
# Exporting PACKET_OPTIC...
# Number of clusters: 2
#
# Cluster -1: 27 data points
#
# Cluster 0: 371 data points
#
# DONE.
# -------------------------------------------------------

# %%
df_anomalies=clustering.optics_anomalies(df,labels)
df_anomalies.sort_values(by=['total_bytes','total_packets','total_duration'],ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-aecc1a6c33e3> in <module>
#       1 df_anomalies=clustering.optics_anomalies(df,labels)
# ----> 2 df_anomalies.sort_values(by=['total_bytes','total_packets','total_duration'],ascending=False)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4984             from pandas.core.sorting import lexsort_indexer
#    4985
# -> 4986             keys = [self._get_label_or_level_values(x, axis=axis) for x in by]
#    4987             indexer = lexsort_indexer(keys, orders=ascending, na_position=na_position)
#    4988             indexer = ensure_platform_int(indexer)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in <listcomp>(.0)
#    4984             from pandas.core.sorting import lexsort_indexer
#    4985
# -> 4986             keys = [self._get_label_or_level_values(x, axis=axis) for x in by]
#    4987             indexer = lexsort_indexer(keys, orders=ascending, na_position=na_position)
#    4988             indexer = ensure_platform_int(indexer)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1772             values = self.axes[axis].get_level_values(key)._values
#    1773         else:
# -> 1774             raise KeyError(key)
#    1775
#    1776         # Check for duplicates
#
# KeyError: 'total_packets'

# %% [markdown]
# # IFOREST

# %%
# model iforest
iforest=clustering.iforest_train(X_Normal)
labels=clustering.iforest_predict(X_Attack,iforest)

# dimensionality reduction
XR=preprocessing.get_pc(X_Attack,2)

# print results
clustering.clustering_print_results(df_Attack,labels,cconfig.SELECTED_FEATURES_FLOW,XR,True,True,dataset_type+'_iforest')
# Out:
# Variability explained by the PC: 0.6448008476225979
#
# Exporting FLOW_IFOREST...
# Number of clusters: 2
#
# Cluster -1: 556 data points
#
# Cluster 1: 247 data points
#
# DONE.
# -------------------------------------------------------

# %%
# get anomalies
df_anomalies=clustering.iforest_anomalies(df_Attack,labels)
df_anomalies.sort_values(by=['total_bytes','total_packets','total_duration'],ascending=False)
# Out:
#                   src             dst                    start  \
# 39382  146.20.128.223   192.168.10.50  2017-07-07 18:58:49.789
# 33305   13.58.146.190   192.168.10.50  2017-07-07 18:56:47.632
# 38475  146.20.128.189   192.168.10.50  2017-07-07 18:58:17.820
# 49362  162.242.240.67   192.168.10.50  2017-07-07 19:03:21.459
# 33309   13.58.146.190   192.168.10.50  2017-07-07 18:56:47.632
# ...               ...             ...                      ...
# 74043    192.168.10.5  198.41.215.185  2017-07-07 18:40:28.288
# 29353   13.58.146.190   192.168.10.50  2017-07-07 18:22:15.969
# 49844   169.54.33.166   192.168.10.50  2017-07-07 18:09:11.460
# 73756    192.168.10.3   192.168.10.50  2017-07-07 17:10:56.416
# 74202    192.168.10.5  209.85.144.155  2017-07-07 17:29:22.099
#
#                         finish  total_duration  total_bytes  total_packets  \
# 39382  2017-07-07 18:58:56.366        6.577682        59450             71
# 33305  2017-07-07 18:56:53.187        5.555633        59450             61
# 38475  2017-07-07 18:58:29.514       11.694282        58075             68
# 49362  2017-07-07 19:03:35.327       13.868009        58075             67
# 33309  2017-07-07 18:56:53.114        5.481896        58075             67
# ...                        ...             ...          ...            ...
# 74043  2017-07-07 18:40:28.304        0.015358            0              3
# 29353  2017-07-07 18:22:15.970        0.000607            0              3
# 49844  2017-07-07 18:09:11.460        0.000442            0              3
# 73756  2017-07-07 17:10:56.416        0.000049            0              3
# 74202  2017-07-07 17:29:22.448        0.349938            0              2
#
#        src_ports  dst_ports           pps  ...         bpp  num_protocols  \
# 39382         80      55177     10.794080  ...  837.323944              2
# 33305         80      49809     10.979850  ...  974.590164              2
# 38475         80      54321      5.814808  ...  854.044118              2
# 49362         80      62768      4.831263  ...  866.791045              2
# 33309         80      49813     12.222050  ...  866.791045              2
# ...          ...        ...           ...  ...         ...            ...
# 74043         80      55774    195.340000  ...    0.000000              1
# 29353      46785         21   4942.000000  ...    0.000000              1
# 49844      64318         22   6787.000000  ...    0.000000              1
# 73756      56422       3268  61224.000000  ...    0.000000              1
# 74202      53748        443      5.715300  ...    0.000000              1
#
#        flag_ack  flag_fin  flag_psh  flag_rst  flag_syn  cluster         x  \
# 39382         5         5         5         3         5       -1  7.351373
# 33305         5         5         5         2         5       -1  6.820765
# 38475         5         5         5         4         5       -1  8.313728
# 49362         5         5         5         5         5       -1  9.057227
# 33309         5         5         5         2         5       -1  6.751117
# ...         ...       ...       ...       ...       ...      ...       ...
# 74043         1         0         0         0         1       -1 -1.570633
# 29353         1         0         0         1         1       -1 -2.342203
# 49844         1         0         0         1         1       -1 -2.496381
# 73756         1         0         0         0         1       -1 -3.610989
# 74202         1         0         0         0         1       -1 -2.622886
#
#               y
# 39382  1.282766
# 33305  0.954123
# 38475  1.575473
# 49362  1.640313
# 33309  1.113758
# ...         ...
# 74043 -2.144456
# 29353 -0.209822
# 49844  0.187883
# 73756 -0.992590
# 74202 -0.073086
#
# [556 rows x 21 columns]

# %% [markdown]
# # LOF

# %%
outliers_fraction=0.05
n_neighbors=30
labels=clustering.lof_fit_predict(X,outliers_fraction,n_neighbors)

# dimensionality reduction
XR=preprocessing.get_pc(X,2)

# print results
clustering.clustering_print_results(df,labels,cconfig.SELECTED_FEATURES_FLOW,XR,True,True,dataset_type+'_lof')
# Out:
# Variability explained by the PC: 0.6202132197616034
#
# Exporting FLOW_LOF...
# Number of clusters: 2
#
# Cluster -1: 71 data points
#
# Cluster 1: 1332 data points
#
# DONE.
# -------------------------------------------------------

# %%
# get anomalies
df_anomalies=clustering.lof_anomalies(df,labels)
df_anomalies.sort_values(by=['total_bytes','total_packets','total_duration'],ascending=False)
# Out:
#                    src             dst                    start  \
# 49362   162.242.240.67   192.168.10.50  2017-07-07 19:03:21.459
# 46334     192.168.10.5  23.208.168.108  2017-07-03 14:07:59.831
# 61300    192.168.10.12   96.16.199.170  2017-07-07 17:19:49.557
# 10445     160.83.8.182    192.168.10.9  2017-07-03 13:32:37.363
# 32848    13.58.146.190   192.168.10.50  2017-07-07 19:05:08.271
# ...                ...             ...                      ...
# 42336  151.101.192.194   192.168.10.50  2017-07-07 17:54:34.909
# 29353    13.58.146.190   192.168.10.50  2017-07-07 18:22:15.969
# 49844    169.54.33.166   192.168.10.50  2017-07-07 18:09:11.460
# 73756     192.168.10.3   192.168.10.50  2017-07-07 17:10:56.416
# 74202     192.168.10.5  209.85.144.155  2017-07-07 17:29:22.099
#
#                         finish  total_duration  total_bytes  total_packets  \
# 49362  2017-07-07 19:03:35.327       13.868009        58075             67
# 46334  2017-07-03 14:08:00.190        0.358903        46803            370
# 61300  2017-07-07 17:19:50.183        0.625521        33820             77
# 10445  2017-07-03 13:32:40.096        2.733070        30863            726
# 32848  2017-07-07 19:05:10.697        2.426649        23230             26
# ...                        ...             ...          ...            ...
# 42336  2017-07-07 17:54:34.910        0.000477            0              4
# 29353  2017-07-07 18:22:15.970        0.000607            0              3
# 49844  2017-07-07 18:09:11.460        0.000442            0              3
# 73756  2017-07-07 17:10:56.416        0.000049            0              3
# 74202  2017-07-07 17:29:22.448        0.349938            0              2
#
#        src_ports  dst_ports           pps  ...         bpp  num_protocols  \
# 49362         80      62768      4.831263  ...  866.791045              2
# 46334      56339        443   1030.920000  ...  126.494595              3
# 61300      47104        443    123.097000  ...  439.220779              3
# 10445        443       2008    265.635000  ...   42.511019              3
# 32848         80      49352     10.714360  ...  893.461538              2
# ...          ...        ...           ...  ...         ...            ...
# 42336      58228        139   8386.000000  ...    0.000000              1
# 29353      46785         21   4942.000000  ...    0.000000              1
# 49844      64318         22   6787.000000  ...    0.000000              1
# 73756      56422       3268  61224.000000  ...    0.000000              1
# 74202      53748        443      5.715300  ...    0.000000              1
#
#        flag_ack  flag_fin  flag_psh  flag_rst  flag_syn  cluster          x  \
# 49362         5         5         5         5         5       -1  11.676296
# 46334         1         0         1         0         1       -1   0.313437
# 61300         1         0         1         0         1       -1  -0.562514
# 10445         1         0         1         0         1       -1   1.598142
# 32848         2         2         2         1         2       -1   2.734096
# ...         ...       ...       ...       ...       ...      ...        ...
# 42336         1         0         0         1         1       -1  -1.822669
# 29353         1         0         0         1         1       -1  -1.708480
# 49844         1         0         0         1         1       -1  -1.844671
# 73756         1         0         0         0         1       -1  -2.905373
# 74202         1         0         0         0         1       -1  -2.062784
#
#               y
# 49362  2.193999
# 46334  5.094990
# 61300  1.953571
# 10445  7.543252
# 32848 -0.861173
# ...         ...
# 42336 -0.652061
# 29353 -0.736011
# 49844 -0.464526
# 73756 -3.295844
# 74202 -0.536631
#
# [71 rows x 21 columns]

# %% [markdown]
# # OCSVM

# %%
# train and test the model
outliers_fraction=0.05
labels=clustering.ocsvm_fit_predict(X_Normal,X_Attack,outliers_fraction)

# dimensionality reduction
XR=preprocessing.get_pc(X_Attack,3)

# print results
clustering.clustering_print_results(df_Attack,labels,cconfig.SELECTED_FEATURES_FLOW,XR,True,True,dataset_type+'_ocsvm')
# Out:
# Variability explained by the PC: 0.7318828183013766
#
# Exporting FLOW_OCSVM...
# Number of clusters: 2
#
# Cluster -1: 438 data points
#
# Cluster 1: 365 data points
#
# DONE.
# -------------------------------------------------------

# %%
# get anomalies
df_anomalies=clustering.ocsvm_anomalies(df_Attack,labels)
df_anomalies.sort_values(by=['total_bytes','total_packets','total_duration'],ascending=False)
# Out:
#                   src             dst                    start  \
# 39382  146.20.128.223   192.168.10.50  2017-07-07 18:58:49.789
# 33305   13.58.146.190   192.168.10.50  2017-07-07 18:56:47.632
# 38475  146.20.128.189   192.168.10.50  2017-07-07 18:58:17.820
# 49362  162.242.240.67   192.168.10.50  2017-07-07 19:03:21.459
# 33309   13.58.146.190   192.168.10.50  2017-07-07 18:56:47.632
# ...               ...             ...                      ...
# 74043    192.168.10.5  198.41.215.185  2017-07-07 18:40:28.288
# 29353   13.58.146.190   192.168.10.50  2017-07-07 18:22:15.969
# 49844   169.54.33.166   192.168.10.50  2017-07-07 18:09:11.460
# 73756    192.168.10.3   192.168.10.50  2017-07-07 17:10:56.416
# 74202    192.168.10.5  209.85.144.155  2017-07-07 17:29:22.099
#
#                         finish  total_duration  total_bytes  total_packets  \
# 39382  2017-07-07 18:58:56.366        6.577682        59450             71
# 33305  2017-07-07 18:56:53.187        5.555633        59450             61
# 38475  2017-07-07 18:58:29.514       11.694282        58075             68
# 49362  2017-07-07 19:03:35.327       13.868009        58075             67
# 33309  2017-07-07 18:56:53.114        5.481896        58075             67
# ...                        ...             ...          ...            ...
# 74043  2017-07-07 18:40:28.304        0.015358            0              3
# 29353  2017-07-07 18:22:15.970        0.000607            0              3
# 49844  2017-07-07 18:09:11.460        0.000442            0              3
# 73756  2017-07-07 17:10:56.416        0.000049            0              3
# 74202  2017-07-07 17:29:22.448        0.349938            0              2
#
#        src_ports  dst_ports           pps  ...         bpp  num_protocols  \
# 39382         80      55177     10.794080  ...  837.323944              2
# 33305         80      49809     10.979850  ...  974.590164              2
# 38475         80      54321      5.814808  ...  854.044118              2
# 49362         80      62768      4.831263  ...  866.791045              2
# 33309         80      49813     12.222050  ...  866.791045              2
# ...          ...        ...           ...  ...         ...            ...
# 74043         80      55774    195.340000  ...    0.000000              1
# 29353      46785         21   4942.000000  ...    0.000000              1
# 49844      64318         22   6787.000000  ...    0.000000              1
# 73756      56422       3268  61224.000000  ...    0.000000              1
# 74202      53748        443      5.715300  ...    0.000000              1
#
#        flag_ack  flag_fin  flag_psh  flag_rst  flag_syn  cluster         x  \
# 39382         5         5         5         3         5       -1  7.351373
# 33305         5         5         5         2         5       -1  6.820765
# 38475         5         5         5         4         5       -1  8.313728
# 49362         5         5         5         5         5       -1  9.057227
# 33309         5         5         5         2         5       -1  6.751117
# ...         ...       ...       ...       ...       ...      ...       ...
# 74043         1         0         0         0         1       -1 -1.570633
# 29353         1         0         0         1         1       -1 -2.342203
# 49844         1         0         0         1         1       -1 -2.496381
# 73756         1         0         0         0         1       -1 -3.610989
# 74202         1         0         0         0         1       -1 -2.622886
#
#               y
# 39382  1.282766
# 33305  0.954123
# 38475  1.575473
# 49362  1.640313
# 33309  1.113758
# ...         ...
# 74043 -2.144456
# 29353 -0.209822
# 49844  0.187883
# 73756 -0.992590
# 74202 -0.073086
#
# [438 rows x 21 columns]
