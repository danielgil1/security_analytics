# %%
import pandas as pd
import sys
sys.path.append("../src")
import cconfig
import utils

# %% [markdown]
# # BiFlow

# %% [markdown]
# ## K-Means - Extreme value based

# %%
df=utils.load("../outputs/BiFlow/BIFLOW_df_anomalies_kmeans_z")

# %%
df.shape

# %%
df.src_ip.value_counts()[:15].plot.pie()

# %%
df.dst_ip.value_counts()[:15].plot.pie()

# %% [markdown]
# ## K-Means - Proximity based

# %%
df=utils.load("../outputs/BiFlow/BIFLOW_df_anomalies_kmeans_anomalies_proximity")

# %%
df.src_ip.value_counts()[:15].plot.pie()

# %%
df.dst_ip.value_counts()[:15].plot.pie()

# %% [markdown]
# ## IForest

# %%
df=utils.load("../outputs/BiFlow/BIFLOW_df_anomalies_iforest")

# %%
df.src_ip.value_counts()[:15].plot.pie()

# %%
df.dst_ip.value_counts()[:10].plot.pie()

# %%
df['conversation']=df[['src_ip', 'dst_ip']].apply(lambda x: '->'.join(x), axis=1)

# %%
malicious_conversations=df.conversation.value_counts()[:11]

# %%
df_ddos=pd.DataFrame(columns=df.columns)
ddos_conversations=list()
for index,row in df.iterrows():
    if row.conversation in malicious_conversations.index:
        ddos_conversations.append(row)

# %%
df_ddos = pd.DataFrame(ddos_conversations)

# %%
df_ddos.sort_values(by=['flow_start'])[['conversation','flow_start','flow_finish']].describe()
# Out:
#                          conversation                  flow_start  \
# count                           77711                       77711
# unique                             11                       27152
# top     162.242.240.67->192.168.10.50  2017-07-07 19:11:28.250000
# freq                            10208                          15
# first                             NaN  2017-07-07 17:14:05.497000
# last                              NaN  2017-07-07 19:16:10.645000
#
#                        flow_finish
# count                        77711
# unique                       26941
# top     2017-07-07 19:12:44.700000
# freq                            33
# first   2017-07-07 17:14:11.505000
# last    2017-07-07 19:16:12.201000

# %%
df[df.conversation=="192.168.10.50"].sort_values(by=['flow_start'])
# Out:
#                src_ip         dst_ip  src_port  dst_port  fwd_packets  \
# 262     192.168.10.12  192.168.10.50     46288        21           16
# 264     192.168.10.12  192.168.10.50     55918      9425           14
# 263     192.168.10.12  192.168.10.50     55918      9425            5
# 504     192.168.10.16  192.168.10.50     43740        21           16
# 506     192.168.10.16  192.168.10.50     57688     40854           14
# ...               ...            ...       ...       ...          ...
# 440020  192.168.10.25  192.168.10.50     54244       139            6
# 440036   192.168.10.5  192.168.10.50     57051        22           25
# 440042   192.168.10.5  192.168.10.50     57052        22           24
# 440114  192.168.10.17  192.168.10.50     37758        22           30
# 440120  192.168.10.17  192.168.10.50     37759        22           32
#
#         bwd_packets  fwd_bytes  bwd_bytes  fwd_duration  \
# 262              20         88        219      0.151695
# 264              10      12201          0      0.008861
# 263               0       8313          0      0.001619
# 504              20         88        220      0.135000
# 506              10      12201          0      0.011234
# ...             ...        ...        ...           ...
# 440020            6        570        558      0.053112
# 440036           31       1216       3477      1.267793
# 440042           30       1196       3317      1.264861
# 440114           32       1212       3425      1.259320
# 440120           31       1364       3265      1.238587
#
#                     flow_start  ...  count_src  count_serv_src  \
# 262    2017-07-07 17:00:06.156  ...          5               0
# 264    2017-07-07 17:00:06.298  ...          6               0
# 263    2017-07-07 17:00:06.305  ...          6               1
# 504    2017-07-07 17:00:20.606  ...          8               0
# 506    2017-07-07 17:00:20.730  ...          9               0
# ...                        ...  ...        ...             ...
# 440020 2017-07-07 20:01:22.096  ...          1               2
# 440036 2017-07-07 20:01:38.851  ...          1               0
# 440042 2017-07-07 20:01:40.119  ...          2               2
# 440114 2017-07-07 20:02:38.306  ...          0               0
# 440120 2017-07-07 20:02:39.567  ...          1               2
#
#         count_serv_dst  count_dest_conn  count_src_conn  count_serv_src_conn  \
# 262                  0                5               5                    0
# 264                  0                6               6                    0
# 263                  0                6               6                    1
# 504                  0               25               8                    0
# 506                  0               26               9                    0
# ...                ...              ...             ...                  ...
# 440020               0                8               8                  100
# 440036               0               22               8                   96
# 440042               0               22               8                   98
# 440114               0               23               8                   88
# 440120               0               23               8                   90
#
#        count_count_serv_src_conn  cluster         x         y
# 262                            0       -1  0.865808  1.726822
# 264                            0       -1  6.271421  1.525353
# 263                            0       -1  8.386832 -0.138331
# 504                            0       -1  1.234036  1.903321
# 506                            0       -1  6.638599  1.701971
# ...                          ...      ...       ...       ...
# 440020                         1       -1  1.048759  0.290177
# 440036                         0       -1  1.702716  3.798608
# 440042                         0       -1  1.609073  3.647407
# 440114                         0       -1  1.712931  3.894375
# 440120                         0       -1  1.782236  3.935357
#
# [78916 rows x 56 columns]

# %% [markdown]
# ## LOF

# %%
df=utils.load("../outputs/BiFlow/BIFLOW_df_anomalies_lof")

# %%
df.src_ip.value_counts()[:15].plot.pie()

# %%
df.dst_ip.value_counts()[:15].plot.bar()

# %% [markdown]
# ## OCSVM

# %%
df=utils.load("../outputs/BiFlow/BIFLOW_df_anomalies_ocsvm")

# %%
df.src_ip.value_counts()[:15].plot.pie()

# %%
df.dst_ip.value_counts()[:10].plot.pie()

# %% [markdown]
# # UniFlow

# %% [markdown]
# ## K-Means - Extreme value based

# %%
df=utils.load("../outputs/UniFlow/FLOW_df_anomalies_kmeans_z")

# %%
df.shape

# %%
df.src_ip.value_counts()[:15].plot.pie()

# %%
df.dst_ip.value_counts()[:15].plot.pie()

# %% [markdown]
# ## K-Means - Proximity based

# %%
df=utils.load("../outputs/UniFlow/FLOW_df_anomalies_kmeans_anomalies_proximity")

# %%
df.src_ip.value_counts()[:15].plot.pie()

# %%
df.dst_ip.value_counts()[:15].plot.pie()

# %% [markdown]
# ## IForest

# %%
df=utils.load("../outputs/UniFlow/FLOW_df_anomalies_iforest")

# %%
df.src_ip.value_counts()[:15].plot.pie()

# %%
df.dst_ip.value_counts()[:15].plot.pie()

# %%
# OCSVM

# %%
df=utils.load("../outputs/UniFlow/FLOW_df_anomalies_ocsvm")

# %%
df.src_ip.value_counts()[:10].plot.pie()

# %%
df.dst_ip.value_counts()[:15].plot.pie()
